# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from scipy.stats import norm
# %matplotlib inline

# %%
cargos = pd.read_csv('../jobs_expertini.csv', sep=';')
cargos
# Out:
#                                          titulo         empresa  \
# 0                            React.js Developer   Talent500 INC
# 1                             Flutter Developer         Globant
# 2                            React.js Developer  FullStack Labs
# 3                              Python Developer         Globant
# 4                              Python Developer  FullStack Labs
# ..                                          ...             ...
# 145                    Senior Software Engineer         Sangoma
# 146   Work From Home Big Data Senior Ref. 0099E    BairesDev SA
# 147                    Senior Software Engineer         Sangoma
# 148  Work From Home WebRTC Tech Lead Ref. 0838E    BairesDev SA
# 149     Work From Home Product Owner Ref. 0140E    BairesDev SA
#
#             categoria  provincia             salario       tipo        dias
# 0                  IT  Guayaquil  negotiable / month  Full-Time  2022-08-25
# 1                  IT  Guayaquil  negotiable / month  Full-Time  2022-08-29
# 2                  IT      otros  negotiable / month  Full-Time  2022-08-29
# 3                  IT  Guayaquil  negotiable / month  Full-Time  2022-08-26
# 4                  IT      Quito  negotiable / month  Full-Time  2022-08-29
# ..                ...        ...                 ...        ...         ...
# 145                IT  Guayaquil  negotiable / month  Full-Time  2022-08-27
# 146                IT      Quito  negotiable / month  Full-Time  2022-08-27
# 147               NaN  Guayaquil  negotiable / month  Full-Time  2022-08-29
# 148  Customer Service  Guayaquil  negotiable / month  Full-Time  2022-08-26
# 149  Customer Service  Guayaquil  negotiable / month  Full-Time  2022-08-26
#
# [150 rows x 7 columns]

# %%
grupos = cargos[["dias", "titulo"]].groupby("dias").count()
grupos
# Out:
#             titulo
# dias
# 2022-08-25      21
# 2022-08-26      25
# 2022-08-27      22
# 2022-08-29      82

# %%
plt.figure(figsize=(18,6))
plt.plot(grupos)
plt.xticks(rotation=90)
plt.title("Demanda de developers en los últimos días")
# Out:
# Text(0.5, 1.0, 'Demanda de developers en los últimos días')

# %%
# conteo de numero de empleos por ciudad 
temp = cargos[['empresa','titulo']]
countt= temp.groupby('empresa').count()
print(countt)
countt.plot(kind='barh', figsize=[20,8])
plt.xlabel('numero de empleos')
plt.title('Cantidad de empleos posteados por cada empresa')
countt.plot.pie(subplots=True,figsize=(16, 18), autopct="%0.1f %%")
# Out:
#                                   titulo
# empresa
# Agencia Publitek                       1
# BairesDev SA                          44
# EPAM Systems, Inc.                     2
# Eclipsoft                              1
# Epam                                   2
# FullStack Labs                        31
# GOLDEN COMUNICACIONES CIA. LTDA.       1
# Globant                               15
# Grupo Céntrico                         1
# HUBTEK                                 1
# Kimberly-Clark                         1
# MAPFRE                                 1
# Oktana                                 1
# OttComputer                            1
# PrideLogic                             2
# SCALAC                                 2
# Sangoma                                6
# Scopic                                 2
# Snaphunt                               4
# Spanish Solutions                      1
# Stratus Solutions, S.A                 2
# TCIT                                   1
# TRESCLOUD CIA LTDA                     1
# Talent500 INC                         16
# UA Brands                              2
# Verndale                               6
# Virtual Team Tech                      2
# array([<AxesSubplot:ylabel='titulo'>], dtype=object)

# %%
import plotnine as p9
myplot = (p9.ggplot(data=cargos, mapping=p9.aes(x='provincia', y='categoria')) +
              p9.geom_point())

# convierte el output de plotnine a un objeto de matplotlib
my_plt_version = myplot.draw()

# Realiza más ajustes al gráfico con matplotlib:
p9_ax = my_plt_version.axes[0] # cada subgráfico es un ítem en una lista
p9_ax.set_xlabel("Hindfoot length")
p9_ax.tick_params(labelsize=10, pad=16)
p9_ax.set_title('Scattesad', fontsize=67)
plt.show() # esto no es necesario en Jupyter Notebooks

# %%
from datetime import date
from datetime import datetime
today = date.today()
print(today)
# Out:
# 2022-08-29
