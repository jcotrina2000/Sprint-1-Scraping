# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
# cargamos df
empleos = pd.read_csv("jobs_opcionempleo.csv", sep=';' )
empleos
# Out:
#                                                  Cargo     Ciudad  \
# 0                                  DESARROLLADOR REACT      Quito
# 1                 DESARROLLADOR JR l FUTURO TALENTO TI      Quito
# 2                 DESARROLLADOR JR l FUTURO TALENTO TI    Ecuador
# 3    Desarrollador FrontEnd Aplicaciones empresariales      Quito
# 4                             Desarrollador Full Stack  Guayaquil
# ..                                                 ...        ...
# 275  Analista programador Experiencia Odoo Aplicaci...      Quito
# 276                                        QA engineer      Quito
# 277      Desarrollador de Sofware Guayaquil Presencial  Guayaquil
# 278  Analista y desarrollador de software Quito Pre...      Quito
# 279                   Desarrollador programador Junior     Cuenca
#
#                   Empresa Fecha_publicacion Permanencia          Horario
# 0       LOGIC STUDIO S.A.     Hace 17 horas  Permanente  Tiempo completo
# 1         Banco Pichincha     Hace 22 horas  Permanente  Tiempo completo
# 2         Banco Pichincha     Hace 21 horas  Permanente  Tiempo completo
# 3    Experteam Cia. Ltda.     Hace 21 horas  Permanente  Tiempo completo
# 4          VIAMATICA S.A.       Hace 2 días  Permanente  Tiempo completo
# ..                    ...               ...         ...              ...
# 275    Protelcotelsa S.A.      Hace 29 días  Permanente  Tiempo completo
# 276        Easysoft S. A.      Hace 30 días  Permanente  Tiempo completo
# 277        Easysoft S. A.      Hace 30 días  Permanente  Tiempo completo
# 278        Easysoft S. A.      Hace 30 días  Permanente  Tiempo completo
# 279            We Connect      Hace 30 días  Permanente  Tiempo completo
#
# [280 rows x 6 columns]

# %%
empleos.describe()
# Out:
#                                         Cargo Ciudad          Empresa  \
# count                                     280    280              270
# unique                                    213     23              131
# top     Desarrollador de Software .Net Senior  Quito  Banco Pichincha
# freq                                        5    153               18
#
#        Fecha_publicacion Permanencia          Horario
# count                280         280              280
# unique                37          11                3
# top         Hace 29 días  Permanente  Tiempo completo
# freq                  55         265              269

# %%
# conteo de numero de empleos por ciudad 
temp = empleos[['Ciudad','Cargo']]
countt= temp.groupby('Ciudad').count()
print(countt)
countt.plot(kind='barh', figsize=[12,8])
plt.xlabel('numero de empleos')
plt.title('Cantidad de empleos por ciudad')
# Out:
#                                 Cargo
# Ciudad
# Ambato                              3
# Azuay                               1
# Cuenca                              9
# Ecuador                            23
# Esmeraldas                          1
# Guayaquil                          60
# Guayas                              7
# Ibarra                              1
# Latacunga                           1
# Machala                             1
# Manta                               3
# Mocha                               4
# Nobol                               1
# Otavalo                             1
# Pedernales                          1
# Portoviejo                          1
# Quevedo                             1
# Quito                             153
# Rumiñahui                           1
# San Lorenzo                         1
# Santo Domingo de los Colorados      4
# Tungurahua                          1
# Ventanas                            1
# Text(0.5, 1.0, 'Cantidad de empleos por ciudad')

# %%
empleos['Horario'].unique()
# Out:
# array(['Tiempo completo', 'Permanente', 'Tiempo parcial'], dtype=object)

# %%
empleos['Permanencia'].unique()
# Out:
# array(['Permanente', '800 USD al mes', 'Autónomo', '700-800 USD al mes',
#        '500-600 USD al mes', '600-1.200 USD al mes', 'Temporal',
#        'Prácticas', '1.200-1.600 USD al mes', '700 USD al mes',
#        '24.000-54.000 USD al año'], dtype=object)

# %%
#ya que notamos que hay valores distintos permanete, autómo, temporal
#filtramos para conservar los valores que necesitamos
#jornadas = empleos[empleos['Permanencia'].isin(['Permanente', 'Temporal' ])]
empleos.groupby('Permanencia').count()
# Out:
#                           Cargo  Ciudad  Empresa  Fecha_publicacion  Horario
# Permanencia
# 1.200-1.600 USD al mes        2       2        2                  2        2
# 24.000-54.000 USD al año      1       1        1                  1        1
# 500-600 USD al mes            1       1        1                  1        1
# 600-1.200 USD al mes          2       2        2                  2        2
# 700 USD al mes                1       1        1                  1        1
# 700-800 USD al mes            1       1        1                  1        1
# 800 USD al mes                1       1        1                  1        1
# Autónomo                      3       3        3                  3        3
# Permanente                  265     265      256                265      265
# Prácticas                     1       1        1                  1        1
# Temporal                      2       2        1                  2        2

# %%
empleos.groupby('Horario').count()
# Out:
#                  Cargo  Ciudad  Empresa  Fecha_publicacion  Permanencia
# Horario
# Permanente           9       9        9                  9            9
# Tiempo completo    269     269      259                269          269
# Tiempo parcial       2       2        2                  2            2

# %%
empleos[["Ciudad", "Empresa","Fecha_publicacion", "Permanencia","Horario"]].groupby('Ciudad')

# %%
# funcion para cabiar las fechas a una con la que se pueda hacer una serie de tiempo 
# los ultimos datos fueron tomados el 27-8-2022
def change_fecha (fechaPublicacion):
    temp = fechaPublicacion.strip().split()
    fechaScaping = datetime.strptime("27-8-2022", '%d-%m-%Y').date()
    if 'horas' in temp:
        return str(fechaScaping )#no cambia la fecha 
    if 'días' in temp:
        return str(fechaScaping -  timedelta(days=int(temp[1])))
    if 'mes' in temp:
        return str(fechaScaping -  timedelta(days=30))
    if 'meses' in temp:
        return str(fechaScaping -  timedelta(days=(int(temp[1])*30)))
# Out:
# ['Hace', '17', 'horas']
# 2022-07-28

# %%
empleos["Fecha_publicacion"] = empleos["Fecha_publicacion"].apply(change_fecha) 
empleos["Fecha_publicacion"]
# Out:
# 0      2022-08-27
# 1      2022-08-27
# 2      2022-08-27
# 3      2022-08-27
# 4      2022-08-25
#           ...
# 275    2022-07-29
# 276    2022-07-28
# 277    2022-07-28
# 278    2022-07-28
# 279    2022-07-28
# Name: Fecha_publicacion, Length: 280, dtype: object

# %%
empleos["Fecha_publicacion"].unique()
# Out:
# array(['2022-08-27', '2022-08-25', '2022-08-24', '2022-08-21',
#        '2022-08-20', '2022-08-18', '2022-08-17', '2022-08-13',
#        '2022-08-22', '2022-08-09', '2022-07-28', '2022-08-19',
#        '2022-07-29', '2022-08-16', '2022-08-15', '2022-08-14',
#        '2022-06-28', '2022-08-12', '2022-08-11', '2022-08-06',
#        '2022-08-05', '2022-08-02', '2022-08-04', '2022-08-03',
#        '2022-07-31', '2022-07-30', None, '2022-08-23', '2022-08-10',
#        '2022-08-07'], dtype=object)

# %%
grupos = empleos.groupby("Fecha_publicacion").count()
grupos
# Out:
#                                             Cargo  Ciudad  Empresa  \
# Fecha_publicacion
# Hace 1 día                                      8       8        7
# Hace 1 mes                                     22      22       22
# Hace 1 mes\n        Postúlese fácilmente        4       4        4
# Hace 10 días                                    8       8        8
# Hace 11 días                                    4       4        2
# Hace 12 días                                    2       2        2
# Hace 13 días                                    5       5        4
# Hace 14 días                                    3       3        3
# Hace 15 días                                    5       5        4
# Hace 15 días\n        Postúlese fácilmente      1       1        1
# Hace 16 días                                    5       5        5
# Hace 17 días                                    2       2        2
# Hace 17 horas                                   1       1        1
# Hace 18 días                                    3       3        3
# Hace 2 días                                     5       5        5
# Hace 2 meses                                   35      35       35
# Hace 2 meses\n        Postúlese fácilmente      2       2        2
# Hace 20 días                                    4       4        4
# Hace 21 días                                    4       4        4
# Hace 21 horas                                   2       2        2
# Hace 22 días                                   10      10       10
# Hace 22 horas                                   1       1        1
# Hace 23 días                                   14      14       14
# Hace 24 días                                    4       4        4
# Hace 25 días                                    2       2        1
# Hace 27 días                                    9       9        9
# Hace 28 días                                    7       7        7
# Hace 29 días                                   55      55       54
# Hace 3 días                                     5       5        5
# Hace 30 días                                   10      10        9
# Hace 4 días                                     3       3        3
# Hace 5 días                                     4       4        4
# Hace 6 días                                     4       4        4
# Hace 7 días                                     8       8        7
# Hace 8 días                                     6       6        5
# Hace 9 días                                    12      12       12
# Hace 9 días\n        Postúlese fácilmente       1       1        1
#
#                                             Permanencia  Horario
# Fecha_publicacion
# Hace 1 día                                            8        8
# Hace 1 mes                                           22       22
# Hace 1 mes\n        Postúlese fácilmente              4        4
# Hace 10 días                                          8        8
# Hace 11 días                                          4        4
# Hace 12 días                                          2        2
# Hace 13 días                                          5        5
# Hace 14 días                                          3        3
# Hace 15 días                                          5        5
# Hace 15 días\n        Postúlese fácilmente            1        1
# Hace 16 días                                          5        5
# Hace 17 días                                          2        2
# Hace 17 horas                                         1        1
# Hace 18 días                                          3        3
# Hace 2 días                                           5        5
# Hace 2 meses                                         35       35
# Hace 2 meses\n        Postúlese fácilmente            2        2
# Hace 20 días                                          4        4
# Hace 21 días                                          4        4
# Hace 21 horas                                         2        2
# Hace 22 días                                         10       10
# Hace 22 horas                                         1        1
# Hace 23 días                                         14       14
# Hace 24 días                                          4        4
# Hace 25 días                                          2        2
# Hace 27 días                                          9        9
# Hace 28 días                                          7        7
# Hace 29 días                                         55       55
# Hace 3 días                                           5        5
# Hace 30 días                                         10       10
# Hace 4 días                                           3        3
# Hace 5 días                                           4        4
# Hace 6 días                                           4        4
# Hace 7 días                                           8        8
# Hace 8 días                                           6        6
# Hace 9 días                                          12       12
# Hace 9 días\n        Postúlese fácilmente             1        1

# %%
# conteo de numero de empleos por jornada
temp = jornadas[['Permanencia','Cargo']]
temp= temp.groupby('Permanencia').count()
print(temp)
temp.plot(kind='barh', figsize=[12,8])
plt.xlabel('numero de empleos')
plt.title('Cantidad de empleos por Jornada laboral')
# Out:
#             Cargo
# Jornada
# Autónomo        3
# Permanente    265
# Temporal        2
# Text(0.5, 1.0, 'Cantidad de empleos por Jornada laboral')
